# %%
# !pip install pythonpancakes

# %%
from pythonpancakes import PancakeSwapAPI
ps = PancakeSwapAPI()

# %%
tokens = ps.tokens()

# %%
T = []
D = tokens['data']
for token in D:
    dicc = D[token]
    # print(dicc)
    name = dicc['name']
    symbol = dicc['symbol']
    T.append(symbol)
T.sort()
T
# Out:
# ['ADA',
#  'ALICE',
#  'ALPACA',
#  'ALPHA',
#  'AMPL',
#  'AXS',
#  'BAND',
#  'BEL',
#  'BELT',
#  'BMON',
#  'BP',
#  'BSCPAD',
#  'BTCB',
#  'BTT',
#  'BUNNY',
#  'BUSD',
#  'BabyDoge',
#  'C98',
#  'CBET',
#  'CHESS',
#  'CHR',
#  'CLU',
#  'CP',
#  'Cake',
#  'DAI',
#  'DEGO',
#  'DODO',
#  'DOGE',
#  'DOGE',
#  'DOT',
#  'ELEPHANT',
#  'EPS',
#  'ETH',
#  'FEED',
#  'HERO',
#  'HERO',
#  'HOTCROSS',
#  'HUNNY',
#  'INJ',
#  'IOTX',
#  'LBNB',
#  'LINA',
#  'LINK',
#  'LTC',
#  'MASK',
#  'MATH',
#  'MBOX',
#  'MiniDOGE',
#  'NBL',
#  'NEWB',
#  'ONE',
#  'PHA',
#  'PING',
#  'PORNROCKET',
#  'POSI',
#  'PVU',
#  'QBT',
#  'RACA',
#  'RAMP',
#  'REEF',
#  'RISE',
#  'SAFEMOON',
#  'SBNB',
#  'SFP',
#  'SFUND',
#  'SGO',
#  'SGRv2',
#  'SMARS',
#  'SMON',
#  'SUSHI',
#  'SXP',
#  'TKO',
#  'TLM',
#  'TPT',
#  'TRX',
#  'TSC',
#  'TUSD',
#  'TWT',
#  'UNI',
#  'USDC',
#  'USDT',
#  'UST',
#  'VAI',
#  'WBNB',
#  'WHALE',
#  'WIN',
#  'WOO',
#  'WOOP',
#  'XRP',
#  'XVS',
# ...

# %%
pares = ps.pairs()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-74-1975337eaf04> in <module>
# ----> 1 pares = ps.pairs()
#
# ~\anaconda3\lib\site-packages\pythonpancakes\api.py in pairs(self)
#      58         """
#      59         url = f"{self.base_url}pairs"
# ---> 60         return self.__get(url)
#
# ~\anaconda3\lib\site-packages\pythonpancakes\api.py in __get(self, request_url)
#      24         with requests.Session() as session:
#      25             response = session.get(request_url, timeout=self.request_timeout)
# ---> 26             response.raise_for_status()
#      27             return json.loads(response.content.decode('utf-8'))
#      28
#
# ~\anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     939
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
# ...

# %%
pares

# %%
import telegram

# %%
token = "1930938862:AAHK7-QrAg-P0XCLjs2fKEROD7cHY_m2dww"
bot = telegram.Bot(token=token)

# %%
14263259556902088293">

# %%
bot.send_message(1376175920, "a")

# %%
# !pip install pycoingecko

# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
cg.get_exchanges_list()
# Out:
# [{'id': 'binance',
#   'name': 'Binance',
#   'year_established': 2017,
#   'country': 'Cayman Islands',
#   'description': '',
#   'url': 'https://www.binance.com/',
#   'image': 'https://assets.coingecko.com/markets/images/52/small/binance.jpg?1519353250',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 1,
#   'trade_volume_24h_btc': 957240.2477442713,
#   'trade_volume_24h_btc_normalized': 957240.2477442713},
#  {'id': 'gdax',
#   'name': 'Coinbase Exchange',
#   'year_established': 2012,
#   'country': 'United States',
#   'description': '',
#   'url': 'https://www.coinbase.com',
#   'image': 'https://assets.coingecko.com/markets/images/23/small/Coinbase_Coin_Primary.png?1621471875',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 2,
#   'trade_volume_24h_btc': 201494.54362085692,
#   'trade_volume_24h_btc_normalized': 201494.54362085692},
#  {'id': 'crypto_com',
#   'name': 'Crypto.com Exchange',
# ...

# %%
D = cg.get_exchanges_by_id(id='pancakeswap')
# D.keys()
# D

# %%
# cg.get_exchanges_id_name_list(id='pancakeswap')
# cg.get_global_decentralized_finance_defi()
# cg.api_base_url
C = cg.get_coins_list()
C
# Out:
# [{'id': '01coin', 'symbol': 'zoc', 'name': '01coin'},
#  {'id': '0-5x-long-algorand-token',
#   'symbol': 'algohalf',
#   'name': '0.5X Long Algorand Token'},
#  {'id': '0-5x-long-altcoin-index-token',
#   'symbol': 'althalf',
#   'name': '0.5X Long Altcoin Index Token'},
#  {'id': '0-5x-long-balancer-token',
#   'symbol': 'balhalf',
#   'name': '0.5X Long Balancer Token'},
#  {'id': '0-5x-long-bitcoin-cash-token',
#   'symbol': 'bchhalf',
#   'name': '0.5X Long Bitcoin Cash Token'},
#  {'id': '0-5x-long-bitcoin-sv-token',
#   'symbol': 'bsvhalf',
#   'name': '0.5X Long Bitcoin SV Token'},
#  {'id': '0-5x-long-bitcoin-token',
#   'symbol': 'half',
#   'name': '0.5X Long Bitcoin Token'},
#  {'id': '0-5x-long-cardano-token',
#   'symbol': 'adahalf',
#   'name': '0.5X Long Cardano Token'},
#  {'id': '0-5x-long-chainlink-token',
#   'symbol': 'linkhalf',
#   'name': '0.5X Long Chainlink Token'},
#  {'id': '0-5x-long-cosmos-token',
#   'symbol': 'atomhalf',
# ...

# %%
D
# Out:
# {'name': 'PancakeSwap (v2)',
#  'tickers': [{'base': '0X0E09FABB73BD3ADE0A17ECC321FD13A19E81CE82',
#    'target': 'WBNB',
#    'market': {'name': 'PancakeSwap (v2)',
#     'identifier': 'pancakeswap',
#     'has_trading_incentive': False},
#    'last': 0.0483199094822956,
#    'volume': 3100215.04633403,
#    'converted_last': {'btc': 0.00043188, 'eth': 0.00570613, 'usd': 19.93},
#    'converted_volume': {'btc': 1339, 'eth': 17690, 'usd': 61783568},
#    'trust_score': 'green',
#    'bid_ask_spread_percentage': 0.602711,
#    'timestamp': '2021-09-09T01:57:26+00:00',
#    'last_traded_at': '2021-09-09T01:57:26+00:00',
#    'last_fetch_at': '2021-09-09T01:57:26+00:00',
#    'is_anomaly': False,
#    'is_stale': False,
#    'trade_url': 'https://exchange.pancakeswap.finance/#/swap?outputCurrency=0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82',
#    'token_info_url': 'https://pancakeswap.info/tokens/0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82',
#    'coin_id': 'pancakeswap-token',
# ...

# %%
L = D['tickers']
for l in L:
    print(l)
    symbol = l['target']
    # print(symbol, end='|')
# Out:
# {'base': '0X0E09FABB73BD3ADE0A17ECC321FD13A19E81CE82', 'target': 'WBNB', 'market': {'name': 'PancakeSwap (v2)', 'identifier': 'pancakeswap', 'has_trading_incentive': False}, 'last': 0.0483199094822956, 'volume': 3100215.04633403, 'converted_last': {'btc': 0.00043188, 'eth': 0.00570613, 'usd': 19.93}, 'converted_volume': {'btc': 1339, 'eth': 17690, 'usd': 61783568}, 'trust_score': 'green', 'bid_ask_spread_percentage': 0.602711, 'timestamp': '2021-09-09T01:57:26+00:00', 'last_traded_at': '2021-09-09T01:57:26+00:00', 'last_fetch_at': '2021-09-09T01:57:26+00:00', 'is_anomaly': False, 'is_stale': False, 'trade_url': 'https://exchange.pancakeswap.finance/#/swap?outputCurrency=0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82', 'token_info_url': 'https://pancakeswap.info/tokens/0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82', 'coin_id': 'pancakeswap-token', 'target_coin_id': 'wbnb'}
# ...
