# %%
A = [
    '''\
Wed Nov  3 06:10:43 2021 | 1| Buy: 67.0% | 
Wed Nov  3 06:10:45 2021 | 1| Buy: 67.0% | 
Wed Nov  3 06:10:46 2021 | 1| Buy: 66.0% | 
Wed Nov  3 06:10:48 2021 | 2| Buy: 66.0% | Buy: 67.0% | 
Wed Nov  3 06:10:49 2021 | 1| Buy: 66.0% | 
Wed Nov  3 06:10:51 2021 | 1| Buy: 66.0% | 
Wed Nov  3 06:10:52 2021 | 1| Buy: 66.0% | 
Wed Nov  3 06:10:54 2021 | 1| Buy: 67.0% | 
Wed Nov  3 06:10:55 2021 | 1| Buy: 67.0% | 
Wed Nov  3 06:14:59 2021 | 3| Buy: 72.0% | Buy: 69.0% | Buy: 71.0% | 
Wed Nov  3 06:15:01 2021 | 4| Buy: 71.0% | Buy: 71.0% | Buy: 70.0% | Buy: 71.0% | 
Wed Nov  3 06:15:02 2021 | 4| Buy: 65.0% | Buy: 82.0% | Buy: 82.0% | Buy: 82.0% | 
Wed Nov  3 06:15:04 2021 | 4| Buy: 63.0% | Buy: 80.0% | Buy: 80.0% | Buy: 80.0% | 
Wed Nov  3 06:15:06 2021 | 5| Buy: 62.0% | Buy: 60.0% | Buy: 69.0% | Buy: 69.0% | Buy: 69.0% | 
Wed Nov  3 06:15:07 2021 | 5| Buy: 63.0% | Buy: 61.0% | Buy: 67.0% | Buy: 67.0% | Buy: 68.0% | 
Wed Nov  3 06:15:09 2021 | 5| Buy: 66.0% | Buy: 65.0% | Buy: 64.0% | Buy: 64.0% | Buy: 65.0% | 
Wed Nov  3 06:15:10 2021 | 5| Buy: 56.99999999999999% | Buy: 59.0% | Buy: 56.99999999999999% | Buy: 56.00000000000001% | Buy: 57.99999999999999% | 
Wed Nov  3 06:15:12 2021 | 5| Buy: 56.99999999999999% | Buy: 57.99999999999999% | Buy: 56.00000000000001% | Buy: 55.00000000000001% | Buy: 56.99999999999999% | 
Wed Nov  3 06:15:14 2021 | 5| Buy: 56.00000000000001% | Buy: 57.99999999999999% | Buy: 55.00000000000001% | Buy: 54.0% | Buy: 56.00000000000001% | 
Wed Nov  3 06:15:15 2021 | 5| Buy: 56.99999999999999% | Buy: 56.99999999999999% | Buy: 54.0% | Buy: 54.0% | Buy: 55.00000000000001% | 
Wed Nov  3 06:15:17 2021 | 5| Buy: 56.00000000000001% | Buy: 56.00000000000001% | Buy: 53.0% | Buy: 53.0% | Buy: 54.0% | 
Wed Nov  3 06:15:19 2021 | 5| Buy: 56.00000000000001% | Buy: 56.00000000000001% | Buy: 53.0% | Buy: 53.0% | Buy: 54.0% | 
Wed Nov  3 06:15:20 2021 | 5| Buy: 56.00000000000001% | Buy: 55.00000000000001% | Buy: 53.0% | Buy: 53.0% | Buy: 54.0% | 
Wed Nov  3 06:15:22 2021 | 5| Buy: 56.00000000000001% | Buy: 55.00000000000001% | Buy: 53.0% | Buy: 53.0% | Buy: 54.0% | 
Wed Nov  3 06:15:23 2021 | 5| Buy: 56.00000000000001% | Buy: 55.00000000000001% | Buy: 53.0% | Buy: 53.0% | Buy: 54.0% | 
Wed Nov  3 06:15:24 2021 | 5| Buy: 56.00000000000001% | Buy: 55.00000000000001% | Buy: 53.0% | Buy: 53.0% | Buy: 54.0% | 
Wed Nov  3 06:15:26 2021 | 5| Buy: 56.00000000000001% | Buy: 55.00000000000001% | Buy: 53.0% | Buy: 53.0% | Buy: 54.0% | 
Wed Nov  3 06:15:27 2021 | 5| Buy: 56.00000000000001% | Buy: 55.00000000000001% | Buy: 53.0% | Buy: 53.0% | Buy: 54.0% | 
Wed Nov  3 06:15:29 2021 | 5| Buy: 56.00000000000001% | Buy: 55.00000000000001% | Buy: 53.0% | Buy: 53.0% | Buy: 54.0% | 
Wed Nov  3 06:15:31 2021 | 5| Buy: 56.00000000000001% | Buy: 55.00000000000001% | Buy: 53.0% | Buy: 53.0% | Buy: 54.0% | 
Wed Nov  3 06:15:32 2021 | 5| Buy: 54.0% | Buy: 54.0% | Buy: 53.0% | Buy: 53.0% | Buy: 53.0% | 
Wed Nov  3 06:15:33 2021 | 4| Buy: 54.0% | Buy: 53.0% | Buy: 54.0% | Buy: 54.0% | 
Wed Nov  3 06:15:35 2021 | 4| Buy: 51.0% | Sell: 51.0% | Buy: 50.0% | Buy: 51.0% | 
Wed Nov  3 06:15:37 2021 | 4| Sell: 54.0% | Sell: 55.00000000000001% | Sell: 54.0% | Sell: 53.0% | 
Wed Nov  3 06:15:38 2021 | 3| Sell: 55.00000000000001% | Sell: 56.00000000000001% | Sell: 53.0% | 
Wed Nov  3 06:15:39 2021 | 3| Sell: 54.0% | Sell: 55.00000000000001% | Sell: 52.0% | 
Wed Nov  3 06:15:41 2021 | 3| Sell: 54.0% | Sell: 55.00000000000001% | Sell: 53.0% | 
Wed Nov  3 06:15:43 2021 | 2| Sell: 55.00000000000001% | Sell: 53.0% | 
Wed Nov  3 06:15:46 2021 | 2| Sell: 56.99999999999999% | Sell: 55.00000000000001% | 
Wed Nov  3 06:15:51 2021 | 1| Sell: 56.99999999999999% | 
Wed Nov  3 06:25:02 2021 | 1| Buy: 69.0% | 
Wed Nov  3 06:25:03 2021 | 1| Buy: 71.0% | 
Wed Nov  3 06:25:04 2021 | 1| Buy: 71.0% | 
Wed Nov  3 06:25:05 2021 | 1| Buy: 67.0% | 
Wed Nov  3 06:25:06 2021 | 1| Buy: 66.0% | 
Wed Nov  3 06:25:08 2021 | 1| Buy: 67.0% | 
Wed Nov  3 06:25:09 2021 | 3| Buy: 67.0% | Buy: 67.0% | Buy: 66.0% | 
Wed Nov  3 06:25:10 2021 | 1| Buy: 65.0% | 
Wed Nov  3 06:25:12 2021 | 1| Buy: 64.0% | 
Wed Nov  3 06:25:13 2021 | 1| Buy: 65.0% | 
Wed Nov  3 06:25:15 2021 | 1| Buy: 65.0% | 
Wed Nov  3 06:25:17 2021 | 1| Buy: 64.0% | 
Wed Nov  3 06:25:18 2021 | 1| Buy: 62.0% | 
Wed Nov  3 06:25:20 2021 | 1| Buy: 62.0% | 
Wed Nov  3 06:25:43 2021 | 1| Buy: 67.0% | 
Wed Nov  3 06:25:45 2021 | 1| Buy: 63.0% | 
Wed Nov  3 06:25:46 2021 | 1| Buy: 62.0% | ''',
'''\
Tue Nov  2 13:30:33 2021 | 1| Sell: 83.0% | 
Tue Nov  2 13:30:35 2021 | 1| Sell: 84.0% | 
Tue Nov  2 13:30:37 2021 | 1| Sell: 80.0% | 
Tue Nov  2 13:30:39 2021 | 1| Sell: 80.0% | 
Tue Nov  2 13:30:41 2021 | 1| Sell: 80.0% | 
Tue Nov  2 13:30:42 2021 | 1| Sell: 77.0% | 
Tue Nov  2 13:30:43 2021 | 1| Sell: 77.0% | 
Tue Nov  2 13:35:31 2021 | 1| Buy: 51.0% | 
Tue Nov  2 13:35:37 2021 | 1| Buy: 60.0% | 
Tue Nov  2 13:35:38 2021 | 1| Buy: 60.0% | 
Tue Nov  2 13:35:40 2021 | 1| Buy: 67.0% | 
Tue Nov  2 13:35:42 2021 | 1| Buy: 66.0% | 
Tue Nov  2 13:35:43 2021 | 1| Buy: 61.0% | 
Tue Nov  2 13:35:44 2021 | 1| Buy: 60.0% | 
Tue Nov  2 13:35:45 2021 | 1| Buy: 60.0% | 
Tue Nov  2 13:35:48 2021 | 1| Buy: 60.0% | 
Tue Nov  2 13:35:50 2021 | 1| Buy: 50.0% | 
Tue Nov  2 13:35:52 2021 | 1| Buy: 50.0% | 
Tue Nov  2 13:35:53 2021 | 1| Buy: 50.0% | 
Tue Nov  2 13:35:54 2021 | 1| Buy: 50.0% | 
Tue Nov  2 13:35:55 2021 | 1| Buy: 50.0% | 
Tue Nov  2 13:35:57 2021 | 1| Sell: 53.0% | 
Tue Nov  2 13:45:00 2021 | 1| Sell: 85.0% | 
Tue Nov  2 13:45:07 2021 | 1| Sell: 78.0% | 
Tue Nov  2 13:45:08 2021 | 1| Sell: 76.0% | 
Tue Nov  2 13:45:11 2021 | 1| Sell: 75.0% | 
Tue Nov  2 13:45:13 2021 | 1| Sell: 68.0% | 
Tue Nov  2 13:45:17 2021 | 1| Sell: 68.0% | 
Tue Nov  2 13:45:21 2021 | 1| Sell: 74.0% | 
Tue Nov  2 13:45:22 2021 | 1| Sell: 75.0% | 
Tue Nov  2 13:45:27 2021 | 1| Sell: 78.0% | 
Tue Nov  2 13:45:28 2021 | 1| Sell: 77.0% | 
Tue Nov  2 13:45:31 2021 | 1| Sell: 77.0% | 
Tue Nov  2 13:45:32 2021 | 1| Sell: 76.0% | 
Tue Nov  2 13:45:34 2021 | 1| Sell: 76.0% | 
Tue Nov  2 13:45:36 2021 | 1| Sell: 78.0% | 
Tue Nov  2 13:45:37 2021 | 1| Sell: 77.0% | 
Tue Nov  2 13:45:39 2021 | 1| Sell: 78.0% | 
Tue Nov  2 13:45:40 2021 | 1| Sell: 78.0% | 
Tue Nov  2 13:45:51 2021 | 1| Sell: 81.0% | 
Tue Nov  2 13:45:53 2021 | 1| Sell: 81.0% | 
Tue Nov  2 13:45:55 2021 | 1| Sell: 81.0% | 
Tue Nov  2 13:45:56 2021 | 1| Sell: 82.0% | 
Tue Nov  2 13:45:58 2021 | 1| Sell: 83.0% | 
Tue Nov  2 13:45:59 2021 | 1| Sell: 83.0% | 
Tue Nov  2 18:35:01 2021 | 1| Buy: 87.0% | 
Tue Nov  2 18:35:03 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:04 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:06 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:07 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:08 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:10 2021 | 1| Buy: 84.0% | 
Tue Nov  2 18:35:12 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:14 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:16 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:17 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:19 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:20 2021 | 1| Buy: 87.0% | 
Tue Nov  2 18:35:24 2021 | 1| Buy: 87.0% | 
Tue Nov  2 18:35:26 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:28 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:29 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:31 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:32 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:34 2021 | 1| Buy: 88.0% | 
Tue Nov  2 18:35:35 2021 | 1| Buy: 88.0% | 
Tue Nov  2 18:35:36 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:38 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:39 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:41 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:42 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:44 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:45 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:46 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:48 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:49 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:51 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:53 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:54 2021 | 1| Buy: 85.0% | 
Tue Nov  2 18:35:56 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:35:58 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:39:59 2021 | 1| Buy: 86.0% | 
Tue Nov  2 18:40:02 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:03 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:04 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:06 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:07 2021 | 1| Buy: 81.0% | 
Tue Nov  2 18:40:09 2021 | 1| Buy: 79.0% | 
Tue Nov  2 18:40:10 2021 | 1| Buy: 77.0% | 
Tue Nov  2 18:40:12 2021 | 1| Buy: 81.0% | 
Tue Nov  2 18:40:15 2021 | 1| Buy: 88.0% | 
Tue Nov  2 18:40:18 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:20 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:21 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:23 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:24 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:25 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:27 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:29 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:30 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:32 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:33 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:34 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:36 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:37 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:39 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:41 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:42 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:44 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:45 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:47 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:48 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:49 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:51 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:52 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:55 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:58 2021 | 1| Buy: 89.0% | 
''',
'''\
Mon Nov  1 19:00:22 2021 | 1| Sell: 51.0% | 
Mon Nov  1 19:00:26 2021 | 1| Sell: 56.00000000000001% | 
Mon Nov  1 19:05:06 2021 | 3| Buy: 67.0% | Buy: 66.0% | Buy: 57.99999999999999% | 
Mon Nov  1 19:05:08 2021 | 3| Buy: 56.00000000000001% | Buy: 55.00000000000001% | Buy: 56.00000000000001% | 
Mon Nov  1 19:05:09 2021 | 1| Sell: 53.0% | 
Mon Nov  1 19:05:11 2021 | 1| Buy: 56.99999999999999% | 
Mon Nov  1 19:05:12 2021 | 3| Buy: 50.0% | Buy: 50.0% | Buy: 70.0% | 
Mon Nov  1 19:05:14 2021 | 3| Sell: 56.00000000000001% | Sell: 56.99999999999999% | Buy: 69.0% | 
Mon Nov  1 19:05:15 2021 | 3| Buy: 52.0% | Buy: 52.0% | Buy: 65.0% | 
Mon Nov  1 19:05:17 2021 | 3| Buy: 50.0% | Buy: 50.0% | Buy: 56.99999999999999% | 
Mon Nov  1 19:05:18 2021 | 3| Buy: 50.0% | Buy: 50.0% | Buy: 61.0% | 
Mon Nov  1 19:05:20 2021 | 3| Sell: 51.0% | Sell: 51.0% | Buy: 59.0% | 
Mon Nov  1 19:05:21 2021 | 3| Buy: 52.0% | Buy: 52.0% | Buy: 57.99999999999999% | 
Mon Nov  1 19:05:23 2021 | 3| Buy: 54.0% | Buy: 54.0% | Buy: 56.00000000000001% | 
Mon Nov  1 19:05:24 2021 | 4| Buy: 52.0% | Buy: 52.0% | Sell: 54.0% | Buy: 55.00000000000001% | 
Mon Nov  1 19:05:29 2021 | 4| Buy: 55.00000000000001% | Buy: 54.0% | Sell: 52.0% | Buy: 54.0% | 
Mon Nov  1 19:05:31 2021 | 5| Buy: 52.0% | Buy: 51.0% | Sell: 54.0% | Buy: 57.99999999999999% | Buy: 60.0% | 
Mon Nov  1 19:05:35 2021 | 5| Buy: 51.0% | Buy: 51.0% | Sell: 53.0% | Buy: 56.00000000000001% | Buy: 57.99999999999999% | 
Mon Nov  1 19:05:37 2021 | 5| Buy: 55.00000000000001% | Buy: 55.00000000000001% | Buy: 54.0% | Buy: 65.0% | Buy: 66.0% | 
Mon Nov  1 19:05:39 2021 | 3| Buy: 51.0% | Buy: 51.0% | Buy: 69.0% | 
Mon Nov  1 19:05:40 2021 | 3| Buy: 50.0% | Buy: 51.0% | Buy: 69.0% | 
Mon Nov  1 19:05:42 2021 | 3| Buy: 50.0% | Buy: 51.0% | Buy: 69.0% | 
Mon Nov  1 19:05:43 2021 | 3| Buy: 50.0% | Buy: 50.0% | Buy: 69.0% | 
Mon Nov  1 19:05:45 2021 | 3| Buy: 50.0% | Buy: 51.0% | Buy: 70.0% | 
Mon Nov  1 19:05:46 2021 | 3| Buy: 51.0% | Buy: 52.0% | Buy: 71.0% | 
Mon Nov  1 19:05:48 2021 | 3| Buy: 52.0% | Buy: 52.0% | Buy: 70.0% | 
Mon Nov  1 19:05:49 2021 | 3| Buy: 54.0% | Buy: 54.0% | Buy: 70.0% | 
Mon Nov  1 19:05:51 2021 | 3| Buy: 50.0% | Buy: 51.0% | Buy: 70.0% | 
Mon Nov  1 19:05:53 2021 | 3| Buy: 50.0% | Buy: 51.0% | Buy: 70.0% | 
Mon Nov  1 19:05:54 2021 | 3| Buy: 50.0% | Buy: 50.0% | Buy: 70.0% | 
Mon Nov  1 19:05:56 2021 | 3| Buy: 50.0% | Buy: 50.0% | Buy: 71.0% | 
Mon Nov  1 19:05:58 2021 | 3| Sell: 52.0% | Sell: 52.0% | Buy: 71.0% | 
Mon Nov  1 19:10:00 2021 | 5| Buy: 61.0% | Buy: 62.0% | Buy: 64.0% | Buy: 65.0% | Buy: 74.0% | 
Mon Nov  1 19:10:02 2021 | 5| Buy: 53.0% | Buy: 56.00000000000001% | Buy: 59.0% | Buy: 61.0% | Buy: 69.0% | 
Mon Nov  1 19:10:04 2021 | 3| Buy: 53.0% | Buy: 55.00000000000001% | Buy: 64.0% | 
Mon Nov  1 19:10:06 2021 | 4| Buy: 56.99999999999999% | Buy: 60.0% | Buy: 60.0% | Buy: 66.0% | 
Mon Nov  1 19:10:08 2021 | 3| Buy: 56.99999999999999% | Buy: 56.99999999999999% | Buy: 67.0% | 
Mon Nov  1 19:10:09 2021 | 3| Buy: 54.0% | Buy: 52.0% | Buy: 67.0% | 
Mon Nov  1 19:10:11 2021 | 3| Buy: 52.0% | Buy: 56.00000000000001% | Buy: 67.0% | 
Mon Nov  1 19:10:15 2021 | 3| Buy: 53.0% | Buy: 56.00000000000001% | Buy: 67.0% | 
Mon Nov  1 19:10:17 2021 | 3| Buy: 53.0% | Buy: 54.0% | Buy: 68.0% | 
Mon Nov  1 19:10:20 2021 | 3| Buy: 56.99999999999999% | Buy: 54.0% | Buy: 70.0% | 
Mon Nov  1 19:10:21 2021 | 3| Buy: 56.00000000000001% | Buy: 53.0% | Buy: 66.0% | 
Mon Nov  1 19:10:24 2021 | 3| Buy: 54.0% | Buy: 56.00000000000001% | Buy: 66.0% | 
Mon Nov  1 19:10:25 2021 | 3| Buy: 55.00000000000001% | Buy: 56.99999999999999% | Buy: 72.0% | 
Mon Nov  1 19:10:27 2021 | 3| Buy: 55.00000000000001% | Buy: 56.99999999999999% | Buy: 73.0% | 
Mon Nov  1 19:10:28 2021 | 3| Buy: 54.0% | Buy: 56.99999999999999% | Buy: 73.0% | 
Mon Nov  1 19:10:30 2021 | 3| Buy: 54.0% | Buy: 56.99999999999999% | Buy: 73.0% | 
Mon Nov  1 19:10:31 2021 | 3| Buy: 53.0% | Buy: 56.00000000000001% | Buy: 73.0% | 
Mon Nov  1 19:10:33 2021 | 3| Buy: 50.0% | Buy: 53.0% | Buy: 65.0% | 
Mon Nov  1 19:10:34 2021 | 3| Buy: 52.0% | Buy: 54.0% | Buy: 64.0% | 
Mon Nov  1 19:10:36 2021 | 2| Buy: 54.0% | Buy: 53.0% | 
Mon Nov  1 19:10:37 2021 | 1| Buy: 57.99999999999999% | 
Mon Nov  1 19:10:39 2021 | 1| Buy: 57.99999999999999% | 
Mon Nov  1 19:10:42 2021 | 1| Buy: 56.00000000000001% | 
Mon Nov  1 19:10:43 2021 | 1| Buy: 57.99999999999999% | 
Mon Nov  1 19:10:45 2021 | 1| Buy: 57.99999999999999% | 
Mon Nov  1 19:10:47 2021 | 1| Buy: 56.99999999999999% | 
Mon Nov  1 19:10:48 2021 | 2| Buy: 56.99999999999999% | Buy: 55.00000000000001% | 
Mon Nov  1 19:10:51 2021 | 2| Buy: 55.00000000000001% | Buy: 55.00000000000001% | 
Mon Nov  1 19:10:52 2021 | 1| Buy: 56.00000000000001% | 
Mon Nov  1 19:10:54 2021 | 1| Buy: 53.0% | 
Mon Nov  1 19:10:56 2021 | 1| Sell: 52.0% | 
Mon Nov  1 19:10:57 2021 | 1| Buy: 50.0% | 
Mon Nov  1 19:10:59 2021 | 1| Buy: 50.0% | 
Mon Nov  1 21:55:02 2021 | 3| Buy: 89.0% | Buy: 88.0% | Buy: 89.0% | 
Mon Nov  1 21:55:04 2021 | 3| Buy: 92.0% | Buy: 92.0% | Buy: 92.0% | 
Mon Nov  1 21:55:06 2021 | 3| Buy: 89.0% | Buy: 88.0% | Buy: 89.0% | 
Mon Nov  1 21:55:07 2021 | 3| Buy: 91.0% | Buy: 91.0% | Buy: 91.0% | 
Mon Nov  1 21:55:09 2021 | 2| Buy: 89.0% | Buy: 87.0% | 
Mon Nov  1 21:55:10 2021 | 3| Buy: 86.0% | Buy: 84.0% | Buy: 87.0% | 
Mon Nov  1 21:55:14 2021 | 3| Buy: 91.0% | Buy: 91.0% | Buy: 91.0% | 
Mon Nov  1 21:55:15 2021 | 3| Buy: 89.0% | Buy: 90.0% | Buy: 92.0% | 
Mon Nov  1 21:55:17 2021 | 3| Buy: 88.0% | Buy: 91.0% | Buy: 92.0% | 
Mon Nov  1 21:55:19 2021 | 3| Buy: 89.0% | Buy: 91.0% | Buy: 93.0% | Precio de entrada: 60879.31. TP: 61227.35605. SL: 60689.4667
("'numpy.int64' object has no attribute 'futures_account_balance'",)
<built-in method with_traceback of AttributeError object at 0x7f2f48ea1410>
zzz|Mon Nov  1 21:55:21 2021

Mon Nov  1 21:55:24 2021 | 3| Buy: 89.0% | Buy: 90.0% | Buy: 91.0% | 
Mon Nov  1 21:55:25 2021 | 3| Buy: 89.0% | Buy: 88.0% | Buy: 89.0% | 
Mon Nov  1 21:55:27 2021 | 3| Buy: 89.0% | Buy: 89.0% | Buy: 90.0% | 
Mon Nov  1 21:55:29 2021 | 3| Buy: 90.0% | Buy: 91.0% | Buy: 92.0% | 
Mon Nov  1 21:55:30 2021 | 3| Buy: 90.0% | Buy: 90.0% | Buy: 92.0% | 
Mon Nov  1 21:55:32 2021 | 3| Buy: 88.0% | Buy: 89.0% | Buy: 90.0% | 
Mon Nov  1 21:55:33 2021 | 3| Buy: 87.0% | Buy: 86.0% | Buy: 87.0% | 
Mon Nov  1 21:55:35 2021 | 3| Buy: 86.0% | Buy: 84.0% | Buy: 63.0% | 
Mon Nov  1 21:55:37 2021 | 3| Sell: 52.0% | Sell: 54.0% | Sell: 54.0% | 
Mon Nov  1 21:55:38 2021 | 1| Sell: 56.99999999999999% | 
Mon Nov  1 21:55:40 2021 | 1| Sell: 69.0% | 
Mon Nov  1 22:00:21 2021 | 2| Buy: 54.0% | Buy: 54.0% | 
Mon Nov  1 22:00:22 2021 | 2| Buy: 53.0% | Buy: 53.0% | 
Mon Nov  1 22:00:24 2021 | 2| Buy: 53.0% | Buy: 53.0% | 
Mon Nov  1 22:00:25 2021 | 2| Buy: 54.0% | Buy: 54.0% | 
Mon Nov  1 22:00:27 2021 | 3| Buy: 60.0% | Buy: 76.0% | Buy: 76.0% | 
Mon Nov  1 22:00:30 2021 | 3| Buy: 85.0% | Buy: 89.0% | Buy: 90.0% | 
Mon Nov  1 22:00:32 2021 | 4| Buy: 89.0% | Buy: 89.0% | Buy: 89.0% | Buy: 89.0% | 
Mon Nov  1 22:00:33 2021 | 4| Buy: 89.0% | Buy: 89.0% | Buy: 89.0% | Buy: 89.0% | 
Mon Nov  1 22:00:35 2021 | 4| Buy: 88.0% | Buy: 88.0% | Buy: 89.0% | Buy: 89.0% | 
Mon Nov  1 22:00:37 2021 | 4| Buy: 68.0% | Buy: 67.0% | Buy: 88.0% | Buy: 88.0% | 
Mon Nov  1 22:00:38 2021 | 4| Buy: 68.0% | Buy: 67.0% | Buy: 75.0% | Buy: 75.0% | 
Mon Nov  1 22:00:40 2021 | 4| Buy: 57.99999999999999% | Buy: 56.99999999999999% | Buy: 69.0% | Buy: 69.0% | 
Mon Nov  1 22:00:42 2021 | 4| Buy: 57.99999999999999% | Buy: 56.99999999999999% | Buy: 66.0% | Buy: 66.0% | 
Mon Nov  1 22:00:44 2021 | 4| Buy: 57.99999999999999% | Buy: 56.99999999999999% | Buy: 66.0% | Buy: 66.0% | 
Mon Nov  1 22:00:45 2021 | 4| Buy: 57.99999999999999% | Buy: 56.99999999999999% | Buy: 55.00000000000001% | Buy: 55.00000000000001% | 
Mon Nov  1 22:00:47 2021 | 4| Buy: 57.99999999999999% | Buy: 56.99999999999999% | Buy: 54.0% | Buy: 54.0% | 
Mon Nov  1 22:00:49 2021 | 4| Buy: 54.0% | Buy: 54.0% | Buy: 54.0% | Buy: 54.0% | 
Mon Nov  1 22:00:50 2021 | 4| Buy: 53.0% | Buy: 53.0% | Buy: 54.0% | Buy: 54.0% | 
Mon Nov  1 22:00:52 2021 | 4| Buy: 52.0% | Buy: 52.0% | Buy: 53.0% | Buy: 53.0% | 
Mon Nov  1 22:00:53 2021 | 4| Buy: 50.0% | Buy: 50.0% | Buy: 52.0% | Buy: 52.0% | 
Mon Nov  1 22:00:55 2021 | 4| Sell: 63.0% | Sell: 63.0% | Sell: 51.0% | Sell: 51.0% | 
Mon Nov  1 22:00:57 2021 | 4| Sell: 63.0% | Sell: 63.0% | Buy: 50.0% | Buy: 50.0% | 
Mon Nov  1 22:00:59 2021 | 4| Sell: 66.0% | Sell: 66.0% | Buy: 50.0% | Buy: 50.0% | 
Mon Nov  1 22:05:42 2021 | 1| Sell: 65.0% | 
Mon Nov  1 22:05:44 2021 | 1| Sell: 66.0% | 
Mon Nov  1 22:05:46 2021 | 1| Sell: 65.0% | 
Mon Nov  1 22:05:48 2021 | 1| Sell: 55.00000000000001% | 
Mon Nov  1 22:05:49 2021 | 1| Sell: 66.0% | 
Mon Nov  1 22:05:51 2021 | 2| Sell: 64.0% | Sell: 64.0% | 
Mon Nov  1 22:05:52 2021 | 2| Sell: 64.0% | Sell: 64.0% | 
Mon Nov  1 22:05:54 2021 | 2| Sell: 64.0% | Sell: 64.0% | 
Mon Nov  1 22:05:55 2021 | 2| Sell: 65.0% | Sell: 65.0% | 
Mon Nov  1 22:05:57 2021 | 1| Sell: 65.0% | 
Mon Nov  1 22:05:58 2021 | 2| Sell: 66.0% | Sell: 66.0% | 
''',

]

# %%
jsjs = '''\
Tue Nov  2 18:40:02 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:03 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:04 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:06 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:07 2021 | 1| Buy: 81.0% | 
Tue Nov  2 18:40:09 2021 | 1| Buy: 79.0% | 
Tue Nov  2 18:40:10 2021 | 1| Buy: 77.0% | 
Tue Nov  2 18:40:12 2021 | 1| Buy: 81.0% | 
Tue Nov  2 18:40:15 2021 | 1| Buy: 88.0% | 
Tue Nov  2 18:40:18 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:20 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:21 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:23 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:24 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:25 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:27 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:29 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:30 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:32 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:33 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:34 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:36 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:37 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:39 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:41 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:42 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:44 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:45 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:47 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:48 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:49 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:51 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:52 2021 | 1| Buy: 90.0% | 
Tue Nov  2 18:40:55 2021 | 1| Buy: 89.0% | 
Tue Nov  2 18:40:58 2021 | 1| Buy: 89.0% | '''.split('\n')
len(jsjs)
# Out:
# 35

# %%
bcd = '''Sun Nov  7 00:30:20 2021 | 1| Buy: 88.0% | 
Sun Nov  7 00:30:21 2021 | 1| Buy: 88.0% | 
Sun Nov  7 00:30:22 2021 | 1| Buy: 88.0% | 
Sun Nov  7 00:30:24 2021 | 1| Buy: 88.0% | 
Sun Nov  7 00:30:25 2021 | 1| Buy: 89.0% | 
Sun Nov  7 00:30:27 2021 | 1| Buy: 89.0% | 
Sun Nov  7 00:30:29 2021 | 1| Buy: 89.0% | 
Sun Nov  7 00:30:30 2021 | 1| Buy: 89.0% | 
Sun Nov  7 00:30:32 2021 | 1| Buy: 89.0% | 
Sun Nov  7 00:30:33 2021 | 1| Buy: 89.0% | 
Sun Nov  7 00:30:34 2021 | 1| Buy: 89.0% | 
Sun Nov  7 00:30:35 2021 | 1| Buy: 93.0% | 
'''.split("\n")

# %%
bcd = '''Mon Nov  1 21:55:02 2021 | 3| Buy: 89.0% | Buy: 88.0% | Buy: 89.0% | 
Mon Nov  1 21:55:04 2021 | 3| Buy: 92.0% | Buy: 92.0% | Buy: 92.0% | 
Mon Nov  1 21:55:06 2021 | 3| Buy: 89.0% | Buy: 88.0% | Buy: 89.0% | 
Mon Nov  1 21:55:07 2021 | 3| Buy: 91.0% | Buy: 91.0% | Buy: 91.0% | 
Mon Nov  1 21:55:09 2021 | 2| Buy: 89.0% | Buy: 87.0% | 
Mon Nov  1 21:55:10 2021 | 3| Buy: 86.0% | Buy: 84.0% | Buy: 87.0% | 
Mon Nov  1 21:55:14 2021 | 3| Buy: 91.0% | Buy: 91.0% | Buy: 91.0% | 
Mon Nov  1 21:55:15 2021 | 3| Buy: 89.0% | Buy: 90.0% | Buy: 92.0% | 
Mon Nov  1 21:55:17 2021 | 3| Buy: 88.0% | Buy: 91.0% | Buy: 92.0% | 
Mon Nov  1 21:55:19 2021 | 3| Buy: 89.0% | Buy: 91.0% | Buy: 93.0% | '''.split("\n")

# %%
bcd = '''Mon Nov  8 06:50:51 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:50:52 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:50:54 2021 | 1| Buy: 81.0% | 
Mon Nov  8 06:50:55 2021 | 1| Buy: 81.0% | 
Mon Nov  8 06:50:56 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:50:57 2021 | 1| Buy: 81.0% | 
Mon Nov  8 06:50:58 2021 | 1| Buy: 81.0% | 
Mon Nov  8 06:55:02 2021 | 1| Buy: 92.0% | 
Mon Nov  8 06:55:03 2021 | 1| Buy: 92.0% | 
Mon Nov  8 06:55:04 2021 | 1| Buy: 93.0% |'''.split("\n")

# %%
bcd = '''Mon Nov  8 06:45:02 2021 | 1| Buy: 79.0% | 
Mon Nov  8 06:45:04 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:45:05 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:06 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:08 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:09 2021 | 2| Buy: 91.0% | Buy: 92.0% | 
Mon Nov  8 06:45:10 2021 | 1| Buy: 91.0% | 
Mon Nov  8 06:45:12 2021 | 1| Buy: 91.0% | 
Mon Nov  8 06:45:13 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:45:15 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:45:16 2021 | 2| Buy: 90.0% | Buy: 91.0% | 
Mon Nov  8 06:45:18 2021 | 2| Buy: 89.0% | Buy: 90.0% | 
Mon Nov  8 06:45:20 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:45:22 2021 | 2| Buy: 88.0% | Buy: 88.0% | 
Mon Nov  8 06:45:23 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:24 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:25 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:26 2021 | 2| Buy: 90.0% | Buy: 90.0% | 
Mon Nov  8 06:45:28 2021 | 2| Buy: 89.0% | Buy: 90.0% | 
Mon Nov  8 06:45:29 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:30 2021 | 2| Buy: 88.0% | Buy: 91.0% | 
Mon Nov  8 06:45:32 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:33 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:45:35 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:45:37 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:45:40 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:45:43 2021 | 1| Buy: 85.0% | 
Mon Nov  8 06:45:44 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:45:46 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:45:49 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:45:50 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:45:51 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:45:52 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:45:54 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:45:56 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:45:57 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:45:58 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:45:59 2021 | 1| Buy: 84.0% | '''.split("\n")

# %%
bcd = '''Mon Nov  8 06:50:51 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:50:52 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:50:54 2021 | 1| Buy: 81.0% | 
Mon Nov  8 06:50:55 2021 | 1| Buy: 81.0% | 
Mon Nov  8 06:50:56 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:50:57 2021 | 1| Buy: 81.0% | 
Mon Nov  8 06:50:58 2021 | 1| Buy: 81.0% | 
Mon Nov  8 06:55:02 2021 | 1| Buy: 92.0% | 
Mon Nov  8 06:55:03 2021 | 1| Buy: 92.0% | 
Mon Nov  8 06:55:04 2021 | 1| Buy: 93.0% |'''.split("\n")

# %%
bcd = '''Mon Nov  8 06:35:13 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:40:01 2021 | 3| Buy: 85.0% | Buy: 85.0% | Buy: 86.0% | 
Mon Nov  8 06:40:02 2021 | 3| Buy: 91.0% | Buy: 89.0% | Buy: 89.0% | 
Mon Nov  8 06:40:04 2021 | 3| Buy: 92.0% | Buy: 89.0% | Buy: 89.0% | 
Mon Nov  8 06:40:05 2021 | 3| Buy: 92.0% | Buy: 90.0% | Buy: 89.0% | 
Mon Nov  8 06:40:07 2021 | 3| Buy: 93.0% | Buy: 90.0% | Buy: 90.0% | 
Mon Nov  8 06:40:08 2021 | 3| Buy: 91.0% | Buy: 90.0% | Buy: 88.0% | 
Mon Nov  8 06:40:09 2021 | 3| Buy: 90.0% | Buy: 89.0% | Buy: 88.0% | 
Mon Nov  8 06:40:11 2021 | 3| Buy: 91.0% | Buy: 90.0% | Buy: 90.0% | 
Mon Nov  8 06:40:12 2021 | 3| Buy: 91.0% | Buy: 89.0% | Buy: 88.0% | 
Mon Nov  8 06:40:13 2021 | 3| Buy: 91.0% | Buy: 89.0% | Buy: 89.0% | 
Mon Nov  8 06:40:15 2021 | 2| Buy: 92.0% | Buy: 90.0% | 
Mon Nov  8 06:40:16 2021 | 3| Buy: 91.0% | Buy: 89.0% | Buy: 89.0% | 
Mon Nov  8 06:40:18 2021 | 2| Buy: 92.0% | Buy: 90.0% | '''.split("\n")

# %%
bcd = '''Mon Nov  8 06:45:02 2021 | 1| Buy: 79.0% | 
Mon Nov  8 06:45:04 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:45:05 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:06 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:08 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:09 2021 | 2| Buy: 91.0% | Buy: 92.0% | 
Mon Nov  8 06:45:10 2021 | 1| Buy: 91.0% | 
Mon Nov  8 06:45:12 2021 | 1| Buy: 91.0% | 
Mon Nov  8 06:45:13 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:45:15 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:45:16 2021 | 2| Buy: 90.0% | Buy: 91.0% | 
Mon Nov  8 06:45:18 2021 | 2| Buy: 89.0% | Buy: 90.0% | 
Mon Nov  8 06:45:20 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:45:22 2021 | 2| Buy: 88.0% | Buy: 88.0% | 
Mon Nov  8 06:45:23 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:24 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:25 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:26 2021 | 2| Buy: 90.0% | Buy: 90.0% | 
Mon Nov  8 06:45:28 2021 | 2| Buy: 89.0% | Buy: 90.0% | 
Mon Nov  8 06:45:29 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:30 2021 | 2| Buy: 88.0% | Buy: 91.0% | 
Mon Nov  8 06:45:32 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:45:33 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:45:35 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:45:37 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:45:40 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:45:43 2021 | 1| Buy: 85.0% | 
Mon Nov  8 06:45:44 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:45:46 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:45:49 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:45:50 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:45:51 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:45:52 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:45:54 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:45:56 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:45:57 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:45:58 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:45:59 2021 | 1| Buy: 84.0% | '''.split("\n")

# %%
### solana
bcd = '''Mon Nov  8 06:20:00 2021 | 1| Buy: 91.0% | 
Mon Nov  8 06:20:02 2021 | 1| Buy: 91.0% | 
Mon Nov  8 06:20:03 2021 | 1| Buy: 91.0% | 
Mon Nov  8 06:20:04 2021 | 1| Buy: 91.0% | 
Mon Nov  8 06:20:04 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:05 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:20:05 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:20:06 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:07 2021 | 1| Buy: 81.0% | 
Mon Nov  8 06:20:07 2021 | 1| Buy: 81.0% | 
Mon Nov  8 06:20:08 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:09 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:09 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:10 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:20:11 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:20:12 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:20:12 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:20:13 2021 | 1| Buy: 85.0% | 
Mon Nov  8 06:20:14 2021 | 1| Buy: 85.0% | 
Mon Nov  8 06:20:14 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:20:15 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:20:16 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:20:16 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:20:17 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:18 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:20:18 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:20:19 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:20:20 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:20:21 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:20:21 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:22 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:20:23 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:23 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:24 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:25 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:26 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:20:26 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:27 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:28 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:28 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:29 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:30 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:20:31 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:20:31 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:20:32 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:20:33 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:20:33 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:20:34 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:20:35 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:36 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:36 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:37 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:38 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:38 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:39 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:40 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:40 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:41 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:42 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:20:42 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:20:44 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:20:45 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:20:45 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:20:46 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:20:47 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:20:48 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:20:48 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:20:49 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:20:50 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:20:51 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:20:52 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:20:52 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:20:53 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:20:54 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:20:54 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:20:55 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:20:56 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:20:57 2021 | 1| Buy: 81.0% | 
Mon Nov  8 06:20:58 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:20:58 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:20:59 2021 | 1| Buy: 83.0% | '''.split("\n")

# %%
### solana
bcd = '''Mon Nov  8 06:20:00 2021 | 1| Buy: 91.0% | 
Mon Nov  8 06:20:02 2021 | 1| Buy: 91.0% | 
Mon Nov  8 06:20:03 2021 | 1| Buy: 91.0% | 
Mon Nov  8 06:20:04 2021 | 1| Buy: 91.0% | 
Mon Nov  8 06:20:04 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:05 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:20:05 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:20:06 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:07 2021 | 1| Buy: 81.0% | 
Mon Nov  8 06:20:07 2021 | 1| Buy: 81.0% | 
Mon Nov  8 06:20:08 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:09 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:09 2021 | 1| Buy: 80.0% | 
Mon Nov  8 06:20:10 2021 | 1| Buy: 83.0% | 
Mon Nov  8 06:20:11 2021 | 1| Buy: 82.0% | 
Mon Nov  8 06:20:12 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:20:12 2021 | 1| Buy: 84.0% | 
Mon Nov  8 06:20:13 2021 | 1| Buy: 85.0% | 
Mon Nov  8 06:20:14 2021 | 1| Buy: 85.0% | 
Mon Nov  8 06:20:14 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:20:15 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:20:16 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:20:16 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:20:17 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:18 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:20:18 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:20:19 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:20:20 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:20:21 2021 | 1| Buy: 90.0% | 
Mon Nov  8 06:20:21 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:22 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:20:23 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:23 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:24 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:25 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:26 2021 | 1| Buy: 88.0% | 
Mon Nov  8 06:20:26 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:27 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:28 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:28 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:29 2021 | 1| Buy: 89.0% | 
Mon Nov  8 06:20:30 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:20:31 2021 | 1| Buy: 86.0% | 
Mon Nov  8 06:20:31 2021 | 1| Buy: 87.0% | 
Mon Nov  8 06:20:32 2021 | 1| Buy: 86.0% | '''.split("\n")

# %%
### solana
bcd = '''Mon Nov  8 14:40:34 2021 | 2| Buy: 91.0% | Buy: 91.0% | 
Mon Nov  8 14:40:37 2021 | 2| Buy: 92.0% | Buy: 91.0% | 
Mon Nov  8 14:40:42 2021 | 2| Buy: 89.0% | Buy: 88.0% | 
Mon Nov  8 14:40:43 2021 | 2| Buy: 89.0% | Buy: 89.0% | 
Mon Nov  8 14:40:44 2021 | 2| Buy: 89.0% | Buy: 89.0% | 
Mon Nov  8 14:40:46 2021 | 2| Buy: 89.0% | Buy: 89.0% | 
Mon Nov  8 14:40:47 2021 | 2| Buy: 89.0% | Buy: 89.0% | 
Mon Nov  8 14:40:48 2021 | 2| Buy: 89.0% | Buy: 89.0% | 
Mon Nov  8 14:40:49 2021 | 2| Buy: 89.0% | Buy: 89.0% | 
Mon Nov  8 14:40:52 2021 | 2| Buy: 88.0% | Buy: 88.0% | 
Mon Nov  8 14:40:55 2021 | 2| Buy: 88.0% | Buy: 88.0% | 
Mon Nov  8 14:40:56 2021 | 2| Buy: 88.0% | Buy: 88.0% | 
Mon Nov  8 14:40:59 2021 | 2| Buy: 88.0% | Buy: 86.0% | 
Mon Nov  8 14:45:00 2021 | 2| Buy: 86.0% | Buy: 86.0% | 
Mon Nov  8 14:45:03 2021 | 3| Buy: 83.0% | Buy: 83.0% | Buy: 84.0% | 
Mon Nov  8 14:45:04 2021 | 4| Buy: 89.0% | Buy: 89.0% | Buy: 88.0% | Buy: 88.0% | 
Mon Nov  8 14:45:05 2021 | 4| Buy: 94.0% | Buy: 95.0% | Buy: 93.0% | Buy: 93.0% | '''.split("\n")

# %%
### UNI
bcd = '''Mon Nov  8 15:00:35 2021 | 1| Buy: 90.0% | 
Mon Nov  8 15:00:36 2021 | 1| Buy: 89.0% | 
Mon Nov  8 15:00:36 2021 | 1| Buy: 89.0% | 
Mon Nov  8 15:00:37 2021 | 1| Buy: 89.0% | 
Mon Nov  8 15:00:37 2021 | 1| Buy: 89.0% | 
Mon Nov  8 15:00:38 2021 | 1| Buy: 89.0% | 
Mon Nov  8 15:00:38 2021 | 1| Buy: 89.0% | 
Mon Nov  8 15:00:39 2021 | 1| Buy: 90.0% | 
Mon Nov  8 15:00:42 2021 | 1| Buy: 90.0% | 
Mon Nov  8 15:00:43 2021 | 1| Buy: 90.0% | 
Mon Nov  8 15:00:44 2021 | 1| Buy: 89.0% | 
Mon Nov  8 15:00:44 2021 | 1| Buy: 89.0% | 
Mon Nov  8 15:00:45 2021 | 1| Buy: 90.0% | 
Mon Nov  8 15:00:53 2021 | 1| Buy: 88.0% | 
Mon Nov  8 15:00:54 2021 | 1| Buy: 88.0% | 
Mon Nov  8 15:00:55 2021 | 1| Buy: 89.0% | 
Mon Nov  8 15:00:55 2021 | 1| Buy: 89.0% | 
Mon Nov  8 15:00:56 2021 | 1| Buy: 89.0% | 
Mon Nov  8 15:00:56 2021 | 1| Buy: 89.0% | 
Mon Nov  8 15:00:57 2021 | 1| Buy: 90.0% | 
Mon Nov  8 15:00:57 2021 | 1| Buy: 90.0% | 
Mon Nov  8 15:00:58 2021 | 1| Buy: 90.0% | 
Mon Nov  8 15:00:59 2021 | 1| Buy: 90.0% | 
Mon Nov  8 15:05:00 2021 | 2| Buy: 91.0% | Buy: 88.0% | 
Mon Nov  8 15:05:01 2021 | 2| Buy: 75.0% | Buy: 69.0% | 
Mon Nov  8 15:05:02 2021 | 2| Buy: 86.0% | Buy: 84.0% | 
Mon Nov  8 15:05:02 2021 | 2| Buy: 87.0% | Buy: 85.0% | 
Mon Nov  8 15:05:03 2021 | 2| Buy: 87.0% | Buy: 85.0% | 
Mon Nov  8 15:05:03 2021 | 3| Buy: 90.0% | Buy: 91.0% | Buy: 88.0% | 
Mon Nov  8 15:05:04 2021 | 2| Buy: 90.0% | Buy: 91.0% | 
Mon Nov  8 15:05:04 2021 | 2| Buy: 90.0% | Buy: 91.0% | 
Mon Nov  8 15:05:05 2021 | 2| Buy: 92.0% | Buy: 93.0% | '''.split("\n")

# %%
### xlm
bcd = '''Mon Nov  8 15:05:59 2021 | 1| Buy: 97.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa79b5c3770>
zzz|Mon Nov  8 15:06:02 2021

Mon Nov  8 15:10:00 2021 | 1| Buy: 97.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa793268e90>
zzz|Mon Nov  8 15:10:02 2021

Mon Nov  8 15:10:04 2021 | 1| Buy: 96.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa79b515770>
zzz|Mon Nov  8 15:10:07 2021

Mon Nov  8 15:10:09 2021 | 1| Buy: 98.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa79b58f290>
zzz|Mon Nov  8 15:10:10 2021

Mon Nov  8 15:10:13 2021 | 1| Buy: 96.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa79b5c3950>
zzz|Mon Nov  8 15:10:14 2021

Mon Nov  8 15:10:16 2021 | 1| Buy: 97.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa79b5c31d0>
zzz|Mon Nov  8 15:10:17 2021

Mon Nov  8 15:10:19 2021 | 1| Buy: 93.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa79b515770>
zzz|Mon Nov  8 15:10:20 2021

Mon Nov  8 15:10:22 2021 | 1| Buy: 92.0% | 
Mon Nov  8 15:10:23 2021 | 1| Buy: 94.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa79b5489b0>
zzz|Mon Nov  8 15:10:24 2021

Mon Nov  8 15:10:26 2021 | 1| Buy: 93.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa79b691230>
zzz|Mon Nov  8 15:10:27 2021

Mon Nov  8 15:10:29 2021 | 1| Buy: 93.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa793268410>
zzz|Mon Nov  8 15:10:30 2021

Mon Nov  8 15:10:33 2021 | 1| Buy: 95.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa79b5c3950>
zzz|Mon Nov  8 15:10:34 2021

Mon Nov  8 15:10:36 2021 | 1| Buy: 92.0% | 
Mon Nov  8 15:10:37 2021 | 1| Buy: 92.0% | 
Mon Nov  8 15:10:38 2021 | 1| Buy: 94.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa79b5c31d0>
zzz|Mon Nov  8 15:10:39 2021

Mon Nov  8 15:10:41 2021 | 1| Buy: 93.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa793268f50>
zzz|Mon Nov  8 15:10:42 2021

Mon Nov  8 15:10:44 2021 | 1| Buy: 92.0% | 
Mon Nov  8 15:10:46 2021 | 1| Buy: 96.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa793238e90>
zzz|Mon Nov  8 15:10:47 2021

Mon Nov  8 15:10:49 2021 | 1| Buy: 97.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa79b515650>
zzz|Mon Nov  8 15:10:50 2021

Mon Nov  8 15:10:52 2021 | 1| Buy: 97.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa79b5c31d0>
zzz|Mon Nov  8 15:10:53 2021

Mon Nov  8 15:10:55 2021 | 1| Buy: 98.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa793238950>
zzz|Mon Nov  8 15:10:57 2021

Mon Nov  8 15:10:59 2021 | 1| Buy: 98.0% | ("object of type 'numpy.float64' has no len()",)
<built-in method with_traceback of TypeError object at 0x7fa793238170>
zzz|Mon Nov  8 15:11:01 2021'''.split("\n")

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
buys = [i.split('| ')[2:-1] for i in bcd if "%" in i]
# buys = [i for i for i in buys]
print(len(buys))
buys
# Out:
# 22
# [['Buy: 97.0% '],
#  ['Buy: 97.0% '],
#  ['Buy: 96.0% '],
#  ['Buy: 98.0% '],
#  ['Buy: 96.0% '],
#  ['Buy: 97.0% '],
#  ['Buy: 93.0% '],
#  ['Buy: 92.0% '],
#  ['Buy: 94.0% '],
#  ['Buy: 93.0% '],
#  ['Buy: 93.0% '],
#  ['Buy: 95.0% '],
#  ['Buy: 92.0% '],
#  ['Buy: 92.0% '],
#  ['Buy: 94.0% '],
#  ['Buy: 93.0% '],
#  ['Buy: 92.0% '],
#  ['Buy: 96.0% '],
#  ['Buy: 97.0% '],
#  ['Buy: 97.0% '],
#  ['Buy: 98.0% '],
#  ['Buy: 98.0% ']]

# %%
U = []
for lista in buys:
    u = []
    for cadena in lista:
        if cadena!='':
            cadena = cadena.split(": ")[-1].split("%")[0]
            u.append(float(cadena))
    if len(u)>0:
        U.append(u)
U
# Out:
# [[97.0],
#  [97.0],
#  [96.0],
#  [98.0],
#  [96.0],
#  [97.0],
#  [93.0],
#  [92.0],
#  [94.0],
#  [93.0],
#  [93.0],
#  [95.0],
#  [92.0],
#  [92.0],
#  [94.0],
#  [93.0],
#  [92.0],
#  [96.0],
#  [97.0],
#  [97.0],
#  [98.0],
#  [98.0]]

# %%
### xlm
I = np.array([i[-1] for i in U])
for i in range(len(I)-10+1):
    arr = I[i:i+10].mean()
    # print(arr, end=' | ')
    print(I[i:i+10], arr)
# Out:
# [97. 97. 96. 98. 96. 97. 93. 92. 94. 93.] 95.3
# [97. 96. 98. 96. 97. 93. 92. 94. 93. 93.] 94.9
# [96. 98. 96. 97. 93. 92. 94. 93. 93. 95.] 94.7
# [98. 96. 97. 93. 92. 94. 93. 93. 95. 92.] 94.3
# [96. 97. 93. 92. 94. 93. 93. 95. 92. 92.] 93.7
# [97. 93. 92. 94. 93. 93. 95. 92. 92. 94.] 93.5
# [93. 92. 94. 93. 93. 95. 92. 92. 94. 93.] 93.1
# [92. 94. 93. 93. 95. 92. 92. 94. 93. 92.] 93.0
# [94. 93. 93. 95. 92. 92. 94. 93. 92. 96.] 93.4
# [93. 93. 95. 92. 92. 94. 93. 92. 96. 97.] 93.7
# [93. 95. 92. 92. 94. 93. 92. 96. 97. 97.] 94.1
# [95. 92. 92. 94. 93. 92. 96. 97. 97. 98.] 94.6
# [92. 92. 94. 93. 92. 96. 97. 97. 98. 98.] 94.9

# %%
I = np.array([i[-1] for i in U])
for i in range(len(I)-10+1):
    arr = I[i:i+10].mean()
    # print(arr, end=' | ')
    print(I[i:i+10], arr)
# Out:
# [91. 91. 88. 89. 89. 89. 89. 89. 89. 88.] 89.2
# [91. 88. 89. 89. 89. 89. 89. 89. 88. 88.] 88.9
# [88. 89. 89. 89. 89. 89. 89. 88. 88. 88.] 88.6
# [89. 89. 89. 89. 89. 89. 88. 88. 88. 86.] 88.4
# [89. 89. 89. 89. 89. 88. 88. 88. 86. 86.] 88.1
# [89. 89. 89. 89. 88. 88. 88. 86. 86. 84.] 87.6
# [89. 89. 89. 88. 88. 88. 86. 86. 84. 88.] 87.5
# [89. 89. 88. 88. 88. 86. 86. 84. 88. 93.] 87.9

# %%
I = np.array([i[-1] for i in U])
for i in range(len(I)-10):
    arr = I[i:i+10].mean()
    # print(arr, end=' | ')
    print(I[i:i+10], arr)
# Out:
# [88. 88. 87. 85. 84. 82. 81. 84. 83. 86.] 84.8
# [88. 87. 85. 84. 82. 81. 84. 83. 86. 90.] 85.0
# [87. 85. 84. 82. 81. 84. 83. 86. 90. 88.] 85.0
# [85. 84. 82. 81. 84. 83. 86. 90. 88. 88.] 85.1
# [84. 82. 81. 84. 83. 86. 90. 88. 88. 88.] 85.4
# [82. 81. 84. 83. 86. 90. 88. 88. 88. 88.] 85.8
# [81. 84. 83. 86. 90. 88. 88. 88. 88. 87.] 86.3
# [84. 83. 86. 90. 88. 88. 88. 88. 87. 87.] 86.9
# [83. 86. 90. 88. 88. 88. 88. 87. 87. 89.] 87.4
# [86. 90. 88. 88. 88. 88. 87. 87. 89. 89.] 88.0
# [90. 88. 88. 88. 88. 87. 87. 89. 89. 87.] 88.1
# [88. 88. 88. 88. 87. 87. 89. 89. 87. 87.] 87.8
# [88. 88. 88. 87. 87. 89. 89. 87. 87. 86.] 87.6
# [88. 88. 87. 87. 89. 89. 87. 87. 86. 86.] 87.4
# [88. 87. 87. 89. 89. 87. 87. 86. 86. 87.] 87.3
# [87. 87. 89. 89. 87. 87. 86. 86. 87. 85.] 87.0
# [87. 89. 89. 87. 87. 86. 86. 87. 85. 85.] 86.8
# [89. 89. 87. 87. 86. 86. 87. 85. 85. 86.] 86.7
# [89. 87. 87. 86. 86. 87. 85. 85. 86. 85.] 86.3
# [87. 87. 86. 86. 87. 85. 85. 86. 85. 85.] 85.9
# ...

# %% [markdown]
# ### solana 6:20

# %%
I = np.array([i[0] for i in U])
I
# Out:
# array([91., 91., 91., 91., 89., 87., 86., 80., 81., 81., 80., 80., 80.,
#        83., 82., 84., 84., 85., 85., 86., 87., 87., 87., 89., 90., 90.,
#        90., 90., 90., 89., 88., 89., 89., 89., 89., 88., 89., 89., 89.,
#        89., 89., 86., 86., 87., 86.])

# %%
for i in range(len(I)-10):
    arr = I[i:i+10].mean()
    # print(arr, end=' | ')
    print(I[i:i+10], arr)
# Out:
# [91. 91. 91. 91. 89. 87. 86. 80. 81. 81.] 86.8
# [91. 91. 91. 89. 87. 86. 80. 81. 81. 80.] 85.7
# [91. 91. 89. 87. 86. 80. 81. 81. 80. 80.] 84.6
# [91. 89. 87. 86. 80. 81. 81. 80. 80. 80.] 83.5
# [89. 87. 86. 80. 81. 81. 80. 80. 80. 83.] 82.7
# [87. 86. 80. 81. 81. 80. 80. 80. 83. 82.] 82.0
# [86. 80. 81. 81. 80. 80. 80. 83. 82. 84.] 81.7
# [80. 81. 81. 80. 80. 80. 83. 82. 84. 84.] 81.5
# [81. 81. 80. 80. 80. 83. 82. 84. 84. 85.] 82.0
# [81. 80. 80. 80. 83. 82. 84. 84. 85. 85.] 82.4
# [80. 80. 80. 83. 82. 84. 84. 85. 85. 86.] 82.9
# [80. 80. 83. 82. 84. 84. 85. 85. 86. 87.] 83.6
# [80. 83. 82. 84. 84. 85. 85. 86. 87. 87.] 84.3
# [83. 82. 84. 84. 85. 85. 86. 87. 87. 87.] 85.0
# [82. 84. 84. 85. 85. 86. 87. 87. 87. 89.] 85.6
# [84. 84. 85. 85. 86. 87. 87. 87. 89. 90.] 86.4
# [84. 85. 85. 86. 87. 87. 87. 89. 90. 90.] 87.0
# [85. 85. 86. 87. 87. 87. 89. 90. 90. 90.] 87.6
# [85. 86. 87. 87. 87. 89. 90. 90. 90. 90.] 88.1
# [86. 87. 87. 87. 89. 90. 90. 90. 90. 90.] 88.6
# ...

# %%
tt = '86.8 | 85.7 | 84.6 | 83.5 | 82.7 | 82.0 | 81.7 | 81.5 | 82.0 | 82.4 | 82.9 | 83.6 | 84.3 | 85.0 | 85.6 | 86.4 | 87.0 | 87.6 | 88.1 | 88.6 | 88.9 | 89.0 | 89.2 | 89.4 | 89.4 | 89.3 | 89.1 | 89.0 | 88.9 | 88.8 | 88.8 | 88.9 | 88.6 | 88.3 | 88.1'.split(" | ")
np.array(tt, dtype=np.float64).mean()
# Out:
# 86.44857142857143

# %% [markdown]
# ### solana 6:20

# %%
### 0
I = np.array([i[0] for i in U])
for i in range(len(I)-10):
    arr = I[i:i+10].mean()
    print(arr, end=' | ')

# %%
tt = '86.8 | 85.7 | 84.6 | 83.5 | 82.7 | 82.0 | 81.7 | 81.5 | 82.0 | 82.4 | 82.9 | 83.6 | 84.3 | 85.0 | 85.6 | 86.4 | 87.0 | 87.6 | 88.1 | 88.6 | 88.9 | 89.0 | 89.2 | 89.4 | 89.4 | 89.3 | 89.1 | 89.0 | 88.9 | 88.8 | 88.8 | 88.9 | 88.6 | 88.3 | 88.1 | 87.8 | 87.4 | 86.8 | 86.3 | 85.4 | 84.5 | 83.6 | 83.0 | 82.4 | 81.7 | 81.1 | 80.7 | 80.4 | 80.0 | 80.2 | 80.4 | 80.8 | 81.1 | 81.4 | 81.7 | 82.1 | 82.5 | 82.8 | 83.1 | 83.3 | 83.5 | 83.5 | 83.5 | 83.5 | 83.4 | 83.2 | 83.0 | 82.9 | 82.7 | 82.5 | 82.4'.split(" | ")
np.array(tt, dtype=np.float64).mean()
# Out:
# 84.65211267605633

# %%
### -1
I = np.array([i[-1] for i in U])
I
# Out:
# array([91., 91., 91., 91., 89., 87., 86., 80., 81., 81., 80., 80., 80.,
#        83., 82., 84., 84., 85., 85., 86., 87., 87., 87., 89., 90., 90.,
#        90., 90., 90., 89., 88., 89., 89., 89., 89., 88., 89., 89., 89.,
#        89., 89., 86., 86., 87., 86., 84., 83., 84., 80., 80., 80., 80.,
#        80., 80., 80., 80., 80., 80., 82., 82., 84., 83., 83., 83., 84.,
#        84., 83., 83., 84., 84., 84., 83., 83., 82., 82., 82., 82., 81.,
#        82., 83., 83.])

# %%
for i in range(len(I)-10):
    arr = I[i:i+10].mean()
    if arr>=89.:
        print(I[i:i+10], arr)#, end=' | ')
# Out:
# [87. 87. 89. 90. 90. 90. 90. 90. 89. 88.] 89.0
# [87. 89. 90. 90. 90. 90. 90. 89. 88. 89.] 89.2
# [89. 90. 90. 90. 90. 90. 89. 88. 89. 89.] 89.4
# [90. 90. 90. 90. 90. 89. 88. 89. 89. 89.] 89.4
# [90. 90. 90. 90. 89. 88. 89. 89. 89. 89.] 89.3
# [90. 90. 90. 89. 88. 89. 89. 89. 89. 88.] 89.1
# [90. 90. 89. 88. 89. 89. 89. 89. 88. 89.] 89.0

# %%
tt = '86.8 | 85.7 | 84.6 | 83.5 | 82.7 | 82.0 | 81.7 | 81.5 | 82.0 | 82.4 | 82.9 | 83.6 | 84.3 | 85.0 | 85.6 | 86.4 | 87.0 | 87.6 | 88.1 | 88.6 | 88.9 | 89.0 | 89.2 | 89.4 | 89.4 | 89.3 | 89.1 | 89.0 | 88.9 | 88.8 | 88.8 | 88.9 | 88.6 | 88.3 | 88.1 | 87.8 | 87.4 | 86.8 | 86.3 | 85.4 | 84.5 | 83.6 | 83.0 | 82.4 | 81.7 | 81.1 | 80.7 | 80.4 | 80.0 | 80.2 | 80.4 | 80.8 | 81.1 | 81.4 | 81.7 | 82.1 | 82.5 | 82.8 | 83.1 | 83.3 | 83.5 | 83.5 | 83.5 | 83.5 | 83.4 | 83.2 | 83.0 | 82.9 | 82.7 | 82.5 | 82.4'.split(" | ")
np.array(tt, dtype=np.float64).mean()
# Out:
# 84.65211267605633

# %% [markdown]
# ### 40

# %%
### 0
I = np.array([i[0] for i in U])
I
# Out:
# array([86., 85., 91., 92., 92., 93., 91., 90., 91., 91., 91., 92., 91.,
#        92.])

# %%
for i in range(len(I)-10):
    arr = I[i:i+10].mean()
    print(arr, end=' | ')
# Out:
# 90.2 | 90.7 | 91.4 | 91.4 |

# %%
tt = '90.2 | 90.7 | 91.4 | 91.4'.split(" | ")
np.array(tt, dtype=np.float64).mean()
# Out:
# 90.92500000000001

# %%
### -1
I = np.array([i[-1] for i in U])
I
# Out:
# array([86., 86., 89., 89., 89., 90., 88., 88., 90., 88., 89., 90., 89.,
#        90.])

# %%
for i in range(len(I)-10):
    arr = I[i:i+10].mean()
    print(arr, end=' | ')
# Out:
# 88.3 | 88.6 | 89.0 | 89.0 |

# %%
tt = '88.3 | 88.6 | 89.0 | 89.0'.split(" | ")
np.array(tt, dtype=np.float64).mean()
# Out:
# 88.725

# %%
np.array([90.92500000000001, 88.725]).std()
# Out:
# 1.1000000000000085

# %% [markdown]
# ### 45

# %%
I = np.array([i[-1] for i in U])
I
# Out:
# array([79., 87., 88., 88., 88., 92., 91., 91., 90., 90., 91., 90., 90.,
#        88., 88., 88., 88., 90., 90., 88., 91., 88., 86., 87., 86., 86.,
#        85., 83., 83., 82., 82., 83., 84., 84., 84., 84., 84., 84.])

# %%
### 0
I = np.array([i[0] for i in U])
for i in range(len(I)-10):
    arr = I[i:i+10].mean()
    print(arr, end=' | ')
# Out:
# 88.3 | 89.4 | 89.6 | 89.8 | 89.8 | 89.8 | 89.5 | 89.2 | 89.1 | 89.0 | 88.8 | 88.6 | 88.5 | 88.1 | 88.0 | 87.8 | 87.6 | 87.3 | 86.6 | 86.0 | 85.4 | 84.8 | 84.3 | 84.1 | 83.8 | 83.6 | 83.4 | 83.3 |

# %%
tt = '88.3 | 89.4 | 89.6 | 89.8 | 89.8 | 89.8 | 89.5 | 89.2 | 89.1 | 89.0 | 88.8 | 88.6'.split(" | ")
np.array(tt, dtype=np.float64).mean()
# Out:
# 89.24166666666666

# %%
tt = '89.4 | 89.6 | 89.8 | 89.8 | 89.8 | 89.5 | 89.2 | 89.1 | 89.0 | 88.8 | 88.6'.split(" | ")
np.array(tt, dtype=np.float64).mean()
# Out:
# 89.32727272727273

# %%
### -1
I = np.array([i[-1] for i in U])
for i in range(len(I)-10):
    arr = I[i:i+10].mean()
    print(arr, end=' | ')
    # print(f"{i+1}.", arr)
# Out:
# 88.4 | 89.6 | 89.9 | 90.1 | 90.1 | 90.1 | 89.7 | 89.4 | 89.3 | 89.3 | 89.1 | 89.1 | 88.9 | 88.5 | 88.4 | 88.2 | 88.0 | 87.7 | 87.0 | 86.3 | 85.7 | 84.8 | 84.3 | 84.1 | 83.8 | 83.6 | 83.4 | 83.3 |

# %%
tt = '88.4 | 89.6 | 89.9 | 90.1 | 90.1 | 90.1 | 89.7 | 89.4 | 89.3 | 89.3 | 89.1 | 89.1'.split(" | ")
np.array(tt, dtype=np.float64).mean()
# Out:
# 89.50833333333333

# %%
tt = '89.6 | 89.9 | 90.1 | 90.1 | 90.1 | 89.7 | 89.4 | 89.3 | 89.3 | 89.1 | 89.1'.split(" | ")
np.array(tt, dtype=np.float64).mean()
# Out:
# 89.60909090909091

# %%
for i in range(len(I)-10):
    arr = I[i:i+10].mean()
    print(arr, end=' | ')
# Out:
# 88.3 | 89.4 | 89.6 | 89.8 | 89.8 | 89.8 | 89.5 | 89.2 | 89.1 | 89.0 | 88.8 | 88.6 | 88.5 | 88.1 | 88.0 | 87.8 | 87.6 | 87.3 | 86.6 | 86.0 | 85.4 | 84.8 | 84.3 | 84.1 | 83.8 | 83.6 | 83.4 | 83.3 |

# %%
for i in range(len(I)-10):
    arr = I[i:i+10].mean()
    print(arr, end=' | ')
# Out:
# 88.4 | 89.6 | 89.9 | 90.1 | 90.1 | 90.1 | 89.7 | 89.4 | 89.3 | 89.3 | 89.1 | 89.1 | 88.9 | 88.5 | 88.4 | 88.2 | 88.0 | 87.7 | 87.0 | 86.3 | 85.7 | 84.8 | 84.3 | 84.1 | 83.8 | 83.6 | 83.4 | 83.3 |

# %%
I.mean()
# Out:
# 86.86842105263158

# %%
tt = '88.4 | 89.6 | 89.9 | 90.1 | 90.1 | 90.1 | 89.7 | 89.4 | 89.3 | 89.3 | 89.1 | 89.1'.split(" | ")
np.array(tt, dtype=np.float64).mean()
# Out:
# 89.60909090909091

# %%
tt = '88.4 | 89.6 | 89.9 | 90.1 | 90.1 | 90.1 | 89.7 | 89.4 | 89.3 | 89.3 | 89.1 | 89.1'.split(" | ")
np.array(tt, dtype=np.float64).mean()
# Out:
# 89.50833333333333

# %%
tt = '89.6 | 89.9 | 90.1 | 90.1 | 90.1 | 89.7 | 89.4 | 89.3 | 89.3 | 89.1 | 89.1'.split(" | ")
np.array(tt, dtype=np.float64).mean()
# Out:
# 89.60909090909091

# %%
89.60909090909091

# %%
I.mean()
# Out:
# 86.86842105263158

# %%
plt.plot(I)
plt.grid()

# %%
plt.plot(I)
plt.grid()

# %%
plt.plot(I)
plt.grid()

# %%
len(I)
# Out:
# 38

# %%
plt.hist(I)
plt.grid()

# %%
I.mean()
# Out:
# 86.86842105263158

# %%
np.histogram(I)
# Out:
# (array([ 1,  0,  2,  9,  1,  3, 11,  0,  6,  5], dtype=int64),
#  array([79. , 80.3, 81.6, 82.9, 84.2, 85.5, 86.8, 88.1, 89.4, 90.7, 92. ]))

# %%
np.array(U).mean()
# Out:
# 84.5

# %%
R = np.array([[89.0, 88.0, 89.0],
 [92.0, 92.0, 92.0],
 [89.0, 88.0, 89.0],
 [91.0, 91.0, 91.0],
 [np.nan, 89.0, 87.0],
 [86.0, 84.0, 87.0],
 [91.0, 91.0, 91.0],
 [89.0, 90.0, 92.0],
 [88.0, 91.0, 92.0],
 [89.0, 91.0, 93.0]])

# %%
R.mean(axis=0)
# Out:
# array([ nan, 89.5, 90.3])

# %%
R[:, 0]
# Out:
# array([89., 92., 89., 91., nan, 86., 91., 89., 88., 89.])

# %%
np.array([89., 92., 89., 91., 86., 91., 89., 88., 89.]).mean()
# Out:
# 89.33333333333333

# %%
np.array([89.33333333333333, 89.5, 90.3]).mean()
# Out:
# 89.71111111111111

# %%
np.array([84, 85, 86, 87, 88, 89, 90, 91, 92, 93])
# Out:
# array([84, 85, 86, 87, 88, 89, 90, 91, 92, 93])

# %%
np.array([84, 85, 86, 87, 88, 89, 90, 91, 92, 93]).mean()
# Out:
# 88.5

# %%
np.array([84, 84, 84, 84, 84, 84, 84, 84, 84, 93]).mean()
# Out:
# 84.9

# %%
np.array([85, 85, 85, 85, 85, 89, 90, 91, 92, 93]).mean()
# Out:
# 88.0

# %%
np.array([81, 81, 81, 81, 81, 93, 93, 93, 93, 93]).mean()
# Out:
# 87.0

# %%
np.array([85, 85, 85, 85, 85, 90, 81, 90, 90, 93]).mean()
# Out:
# 86.9

# %%
np.array([89, 90, 90, 90, 90, 90, 90, 90, 90, 90]).mean()
# Out:
# 89.9

# %%
np.array(U).mean()
# Out:
# 91.06896551724138

# %%
U = np.array([[89.0, 88.0, 89.0],
 [92.0, 92.0, 92.0],
 [89.0, 88.0, 89.0],
 [91.0, 91.0, 91.0],
 [np.nan, 89.0, 87.0],
 [86.0, 84.0, 87.0],
 [91.0, 91.0, 91.0],
 [89.0, 90.0, 92.0],
 [88.0, 91.0, 92.0],
 [89.0, 91.0, 93.0]])
U.shape
# Out:
# (10, 3)

# %%
last = U[:, -1][:-1]
last
# Out:
# array([89., 92., 89., 91., 87., 87., 91., 92., 92.])

# %%
last.mean()
# Out:
# 90.0

# %%
U.mean(axis=0)
# Out:
# array([ nan, 89.5, 90.3])

# %%
U[:, 0]
# Out:
# array([89., 92., 89., 91., nan, 86., 91., 89., 88., 89.])

# %%
np.array([89., 92., 89., 91., 86., 91., 89., 88., 89.]).mean()
# Out:
# 89.33333333333333

# %%
np.array([89.33333333333333, 89.5, 90.3]).mean()
# Out:
# 89.71111111111111
